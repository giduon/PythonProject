# %%
import pandas as pd
import folium # pip install folium
import seaborn as sns # pip install seaborn
import matplotlib.pyplot as plt
import plotly.express as px # pip install plotly

from collections import Counter
# from keplergl import KeplerGl

plt.rc('font', family='Malgun Gothic') # 한글 폰트 설정 (Malgun Gothic)
plt.rc('axes', unicode_minus=False) # 마이너스 기호 깨짐 방지

# 공용 변수 선언
dataIn = './../dataIn/'
dataOut = './../dataOut/'

# %%
# 이미 생성해 놓은 매장 정보 파일을 읽어 옵니다.
starbucks = pd.read_csv(dataOut + 'starbucks.csv')
ediya = pd.read_csv(dataOut + 'ediya_file.csv')
hollysBefore = pd.read_csv(dataOut + 'hollys_file.csv')

# %%
print(f'스타벅스 매장 갯수 : {len(starbucks)}')
print(f'이디야 매장 갯수 : {len(ediya)}')
print(f'할리스 매장 갯수 : {len(hollysBefore)}')
# Out:
# 스타벅스 매장 갯수 : 665
# 이디야 매장 갯수 : 463
# 할리스 매장 갯수 : 122

# %%
starbucks.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
ediya.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
hollysBefore.columns
# Out:
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도', '전화 번호', '24시간', 'DT 매장',
#        '주차', '테라스', '흡연시설'],
#       dtype='object')

# %%
print('스타벅스와 할리스의 공통 컬럼 정보')
common_col = starbucks.columns.intersection(hollysBefore.columns)
common_col
# Out:
# 스타벅스와 할리스의 공통 컬럼 정보
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
print('# 다른 매장들과 공통된 컬럼들만 따로 추출')
hollys = hollysBefore[common_col]
hollys.columns
# Out:
# # 다른 매장들과 공통된 컬럼들만 따로 추출
# Index(['브랜드', '상호', '주소', '시도', '군구', '위도', '경도'], dtype='object')

# %%
print('# 각 매장의 데이터 프레임을 하나로 모아줍니다')
coffeeFrame = pd.concat([starbucks, ediya, hollys], axis=0)
print(f'전체 매장 갯수 : {len(coffeeFrame)}')
# Out:
# # 각 매장의 데이터 프레임을 하나로 모아줍니다
# 전체 매장 갯수 : 1250

# %%
filename = dataOut + 'coffee_list.csv'
coffeeFrame.to_csv(filename, index=False, encoding='UTF-8')
print(f'{filename} 파일이 저장되었습니다.')
# Out:
# ./../dataOut/coffee_list.csv 파일이 저장되었습니다.

# %%
coffeeFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1250 entries, 0 to 121
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   브랜드     1250 non-null   object
#  1   상호      1250 non-null   object
#  2   주소      1250 non-null   object
#  3   시도      1250 non-null   object
#  4   군구      1250 non-null   object
#  5   위도      1248 non-null   float64
#  6   경도      1248 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 78.1+ KB

# %%
print(f'위도/경도 결측지 제거전 : {len(coffeeFrame)}')
# Out:
# 위도/경도 결측지 제거전 : 1250

# %%
# notnull() 함수는 결측치가 아니면 True를 반환해주는 함수 ↔ isnull()
mapFrame = coffeeFrame[coffeeFrame['위도'].notnull()]

print(f'위도/경도 결측지 제거후 : {len(mapFrame)}')
# Out:
# 위도/경도 결측지 제거후 : 1248

# %%
# 지도 위에 매장 표시
# folium에서 사용할 브랜드별 색상 지정
brand_colors = {
    '스타벅스': 'beige',
    '이디야': 'darkpurple',
    '할리스': 'lightblue'
}

seoul_center = [mapFrame['위도'].mean(), mapFrame['경도'].mean()] # 서울 중심 위치
seoul_center
# Out:
# [np.float64(37.5423630436092), np.float64(126.98784014591867)]

# %%
# 서울 지도 객체
seoul_map = folium.Map(location=seoul_center, zoom_start=11)

# iterrows() : iterable rows(전체 행을 반복)
# for 색인_번호, 데이터_1행 in mapFrame.iterrows():
# 찾아 볼것 : 마커 크기 조정, popup의 모양
for _, row in mapFrame.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=f"{row['상호']}({row['브랜드']})", # 팝업 예시 : xxx점(스타벅스)
        icon=folium.Icon(color=brand_colors.get(row['브랜드'], 'gray'))
    ).add_to(seoul_map)
# end for

htmlfile = dataOut + 'coffee_map.html'
seoul_map.save(htmlfile)
print(f'{htmlfile} 파일 생성')
# Out:
# ./../dataOut/coffee_map.html 파일 생성

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3fdd4d76d8faad58fdee22e4958d9ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3fdd4d76d8faad58fdee22e4958d9ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3fdd4d76d8faad58fdee22e4958d9ab = L.map(
#                 &quot;map_b3fdd4d76d8faad58fdee22e4958d9ab&quot;,
#                 {
#                     center: [37.5423630436092, 126.98784014591867],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a858a7e68bc08469c2c388c215f22ac8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a858a7e68bc08469c2c388c215f22ac8.addTo(map_b3fdd4d76d8faad58fdee22e4958d9ab);
#
#
#             var marker_3373e72a082c348b36a58aef492b71b0 = L.marker(
#                 [37.501087, 127.043069],
#                 {
# }
#             ).addTo(map_b3fdd4d76d8faad58fdee22e4958d9ab);
#
#
#             var icon_75e5ff29eac1898d3692ba15006755a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db0d809918b8380d2fec02e5a02de004 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5da27bee89e7c3cacbbcb738ce06df3a = $(`&lt;div id=&quot;html_5da27bee89e7c3cacbbcb738ce06df3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_db0d809918b8380d2fec02e5a02de004.setContent(html_5da27bee89e7c3cacbbcb738ce06df3a);
#
#
#
#         marker_3373e72a082c348b36a58aef492b71b0.bindPopup(popup_db0d809918b8380d2fec02e5a02de004)
#         ;
#
#
#
#
#                 marker_3373e72a082c348b36a58aef492b71b0.setIcon(icon_75e5ff29eac1898d3692ba15006755a3);
#
#
#             var marker_ff8211059fc14a34af8bdbe2b2271060 = L.marker(
#                 [37.510178, 127.022223],
#                 {
# }
#             ).addTo(map_b3fdd4d76d8faad58fdee22e4958d9ab);
#
#
#             var icon_3122511705753669c9ecb9d151208077 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7f0c259131fd9f9d8bed7765b1a4595b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e627418e0ac2192324d060925f7b644 = $(`&lt;div id=&quot;html_0e627418e0ac2192324d060925f7b644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_7f0c259131fd9f9d8bed7765b1a4595b.setContent(html_0e627418e0ac2192324d060925f7b644);
#
#
#
#         marker_ff8211059fc14a34af8bdbe2b2271060.bindPopup(popup_7f0c259131fd9f9d8bed7765b1a4595b)
#         ;
#
#
#
#
#                 marker_ff8211059fc14a34af8bdbe2b2271060.setIcon(icon_3122511705753669c9ecb9d151208077);
#
#
#             var marker_e6a9200d24a8f14e35eb05ee823f5342 = L.marker(
#                 [37.5139309, 127.0206057],
#                 {
# }
#             ).addTo(map_b3fdd4d76d8faad58fdee22e4958d9ab);
#
#
#             var icon_ca4258a7db143e4bde9d41ace8a7b9e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_be61424658baec67e2567d000152c80e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0e88bd5ef4f84da75d70724cfb3178d = $(`&lt;div id=&quot;html_a0e88bd5ef4f84da75d70724cfb3178d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;리저브 매장 2번(스타벅스)&lt;/div&gt;`)[0];
#                 popup_be61424658baec67e2567d000152c80e.setContent(html_a0e88bd5ef4f84da75d70724cfb3178d);
#
#
#
#         marker_e6a9200d24a8f14e35eb05ee823f5342.bindPopup(popup_be61424658baec67e2567d000152c80e)
#         ;
#
#
#
#
#                 marker_e6a9200d24a8f14e35eb05ee823f5342.setIcon(icon_ca4258a7db143e4bde9d41ace8a7b9e0);
#
#
#             va

# %%
print('# 군구 컬럼이 마포구, 용산구, 서대문구인 항목들만 추출')
concern_gu = ['마포구', '용산구', '서대문구']
myfilter01 = mapFrame[mapFrame['군구'].isin(concern_gu)]
print(f'데이터 갯수 : {len(myfilter01)}')
# Out:
# # 군구 컬럼이 마포구, 용산구, 서대문구인 항목들만 추출
# 데이터 갯수 : 153

# %%
myfilter01.head()
# Out:
#       브랜드         상호                           주소     시도   군구         위도  \
# 223  스타벅스  리저브 매장 2번       서울특별시 마포구 백범로 35 (신수동)  서울특별시  마포구  37.551027
# 224  스타벅스  리저브 매장 2번      서울특별시 마포구 상암산로 76 (상암동)  서울특별시  마포구  37.579314
# 225  스타벅스  리저브 매장 2번      서울특별시 마포구 토정로 295 (용강동)  서울특별시  마포구  37.541186
# 226  스타벅스  리저브 매장 2번      서울특별시 마포구 양화로 125 (서교동)  서울특별시  마포구  37.554636
# 227  스타벅스  리저브 매장 2번  서울특별시 마포구 마포대로 173-14 (아현동)  서울특별시  마포구  37.550800
#
#              경도
# 223  126.943134
# 224  126.892210
# 225  126.942209
# 226  126.920360
# 227  126.953432

# %%
my_center = [myfilter01['위도'].mean(), myfilter01['경도'].mean()]

filter_map = folium.Map(location=my_center, zoom_start=13, tiles='OpenStreetMap')

for _, row in myfilter01.iterrows():
    # 브랜드별로 색상을 다르게 지정하려면 brand_colors에 추가하는 방법도 고려해 보세요.
    ic_color = 'white' # 아이콘 색상

    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['주소'],
        tooltip=f"{row['상호']}({row['브랜드']})",
        icon=folium.Icon(
            color=brand_colors.get(row['브랜드'], 'gray'),
            icon_color=ic_color,
            icon='coffee',
            prefix='fa'
        )
    ).add_to(filter_map)
# end for

htmlfile = dataOut + 'coffee_map_02.html'
seoul_map.save(htmlfile)
print(f'{htmlfile} 파일 생성')
# Out:
# ./../dataOut/coffee_map_02.html 파일 생성

# %%
filter_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f9089eac0879b793945e78b34ccb731 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f9089eac0879b793945e78b34ccb731&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f9089eac0879b793945e78b34ccb731 = L.map(
#                 &quot;map_1f9089eac0879b793945e78b34ccb731&quot;,
#                 {
#                     center: [37.55303470839617, 126.94298304202718],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e7342cd68104d02e88ced6af10df1f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e7342cd68104d02e88ced6af10df1f0.addTo(map_1f9089eac0879b793945e78b34ccb731);
#
#
#             var marker_902d501e7924461c2f210da37ffa6e62 = L.marker(
#                 [37.55102696988243, 126.94313374835716],
#                 {
# }
#             ).addTo(map_1f9089eac0879b793945e78b34ccb731);
#
#
#             var icon_87d9dff23bba95f76f022086fb4ae29a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8b5f7f1e5e88279ccd6851eec97a2f06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59a26e72882f0f43fc2b123e760442c3 = $(`&lt;div id=&quot;html_59a26e72882f0f43fc2b123e760442c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 마포구 백범로 35 (신수동)&lt;/div&gt;`)[0];
#                 popup_8b5f7f1e5e88279ccd6851eec97a2f06.setContent(html_59a26e72882f0f43fc2b123e760442c3);
#
#
#
#         marker_902d501e7924461c2f210da37ffa6e62.bindPopup(popup_8b5f7f1e5e88279ccd6851eec97a2f06)
#         ;
#
#
#
#
#             marker_902d501e7924461c2f210da37ffa6e62.bindTooltip(
#                 `&lt;div&gt;
#                      리저브 매장 2번(스타벅스)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_902d501e7924461c2f210da37ffa6e62.setIcon(icon_87d9dff23bba95f76f022086fb4ae29a);
#
#
#             var marker_7f180641c3b62b0edaf2726eb4111ae8 = L.marker(
#                 [37.57931426554629, 126.89221044590168],
#                 {
# }
#             ).addTo(map_1f9089eac0879b793945e78b34ccb731);
#
#
#             var icon_f1da60d8ea2822355b44e2d7ac202044 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fb51fe09d71100a938ad8e9445e84221 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ddd13c7bf12eb88f9422fcd1aa46494 = $(`&lt;div id=&quot;html_2ddd13c7bf12eb88f9422fcd1aa46494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 마포구 상암산로 76 (상암동)&lt;/div&gt;`)[0];
#                 popup_fb51fe09d71100a938ad8e9445e84221.setContent(html_2ddd13c7bf12eb88f9422fcd1aa46494);
#
#
#
#         marker_7f180641c3b62b0edaf2726eb4111ae8.bindPopup(popup_fb51fe09d71100a938ad8e9445e84221)
#         ;
#
#
#
#
#             marker_7f180641c3b62b0edaf2726eb4111ae8.bindTooltip(
#                 `&lt;div&gt;
#                      리저브 매장 2번(스타벅스)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7f180641c3b62b0edaf2726eb4111ae8.setIcon(icon_f1da60d8ea2822355b44e2d7ac202044);
#
#
#             var marker_41c93f6a4b05e960db8fd08a4d420de2 = L.marker(
#                 [37.541186, 126.942209],
#                 {
# }
#             ).addTo(map_1f9089eac0879b793945e78b34ccb731);
#
#
#             var icon_d9d61db91108448af5226f39246a7ec9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;beige&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_11907348607da67287231bac86f434a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae03c2a0ab996054d4ec85566b7958e7 = $(`&lt;div id=&quot;html_ae03c2a0ab996054d4ec85
